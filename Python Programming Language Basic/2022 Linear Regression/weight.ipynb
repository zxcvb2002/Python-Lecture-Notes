# %%
x = [30, 100, 120, 170, 50]
y = [20, 60, 70, 80, 25]

w = 0.53

m = len(x)
# loss = 1/m*sig(w*x-y)**2

sigma = 0
for i in range(m):
    sigma += ((w*x[i]-y[i]))**2
    
loss = sigma/m

print(loss)
# Out:
# 42.20600000000003

# %%
x = [30, 100, 120, 170, 50]
y = [20, 60, 70, 80, 25]

w_n = 0.53
a = 0.0001

m = len(x)
# loss = 1/m*sig(w*x-y)**2

sigma = 0
for i in range(m):
    sigma += ((w_n * x[i] - y[i]) * x[i])
loss_m = sigma * 2 / m

w_n1 = w_n - (a * loss_m)

print(w_n1)
# Out:
# 0.52196

# %%
x = [30, 100, 120, 170, 50]
y = [20, 60, 70, 80, 25]

w_n = 0.53
a = 0.0001
m = len(x)
# loss = 1/m*sig(w*x-y)**2

sigma = 0
for i in range(m):
    sigma += ((w_n * x[i] - y[i]) * x[i])
loss_m = sigma * 2/m

for i in range(m):
    sigma += ((w_n * x[i] - y[i]))**2
loss = sigma / m

w_n1 = w_n - (a * loss_m)

print('가중치 =',w_n1, 'Loss =',loss)
# Out:
# 가중치 = 0.52196 Loss = 82.40600000000035

# %%
x = [30, 100, 120, 170, 50]
y = [20, 60, 70, 80, 25]

iteration = 100
w_n = 0.53
a = 0.0001
m = len(x)
# loss = 1/m*sig(w*x-y)**2

for j in range(1,iteration+1):
    sigma = 0
    for i in range(m):
        sigma += ((w_n * x[i] - y[i]) * x[i]) 
    loss_m = sigma * 2 / m

    for i in range(m):
        sigma += ((w_n*x[i])-y[i])**2
    
    loss = sigma/m

    w_n1 = w_n - (a * loss_m)

    print('가중치 =',w_n1, 'Loss =',loss)
    w_n = w_n1
# Out:
# 가중치 = 0.52196 Loss = 82.40600000000035
# 가중치 = 0.5321547200000001 Loss = -8.680980256000247
# 가중치 = 0.5192278150399999 Loss = 107.06641384727803
# 가중치 = 0.5356191305292801 Loss = -39.30076787085172
# 가중치 = 0.5148349424888728 Loss = 146.93677457703438
# 가중치 = 0.5411892929241092 Loss = -88.17706128803539
# 가중치 = 0.5077719765722295 Loss = 211.61197204194173
# 가중치 = 0.5501451337064129 Loss = -165.84399456527746
# 가중치 = 0.49641597046026836 Loss = 317.07355649335693
# 가중치 = 0.5645445494563797 Loss = -288.3468119205271
# 가중치 = 0.4781575112893105 Loss = 490.4508882852547
# 가중치 = 0.5876962756851543 Loss = -479.1780792425167
# 가중치 = 0.4488011224312244 Loss = 779.0698218195452
# 가중치 = 0.6249201767572075 Loss = -770.1501188594599
# 가중치 = 0.40160121587186093 Loss = 1268.6039717347371
# 가중치 = 0.6847696582744804 Loss = -1197.005424595272
# 가중치 = 0.3257120733079587 Loss = 2121.5717637258867
# 가중치 = 0.7809970910455084 Loss = -1777.3853017030015
# 가중치 = 0.20369568855429532 Loss = 3663.3079589250287
# ...

# %%
x = [30, 100, 120, 170, 50]
y = [20, 60, 70, 80, 25]

iteration = 100
w_n = 0.53
a = 0.0001
m = len(x)
# loss = 1/m*sig(w*x-y)**2

for j in range(1,iteration+1):
    sigma = 0
    for i in range(m):
        sigma += ((w_n * x[i] - y[i]) * x[i]) 
    loss_m = sigma * 2 / m

    for i in range(m):
        sigma += ((w_n*x[i])-y[i])**2
    
    loss = sigma/m

    w_n1 = w_n - (a * loss_m)

    print('iteration =', j, '가중치 =',w_n1, 'Loss =',loss)
    w_n = w_n1
# Out:
# iteration = 1 가중치 = 0.52196 Loss = 82.40600000000035
# iteration = 2 가중치 = 0.5321547200000001 Loss = -8.680980256000247
# iteration = 3 가중치 = 0.5192278150399999 Loss = 107.06641384727803
# iteration = 4 가중치 = 0.5356191305292801 Loss = -39.30076787085172
# iteration = 5 가중치 = 0.5148349424888728 Loss = 146.93677457703438
# iteration = 6 가중치 = 0.5411892929241092 Loss = -88.17706128803539
# iteration = 7 가중치 = 0.5077719765722295 Loss = 211.61197204194173
# iteration = 8 가중치 = 0.5501451337064129 Loss = -165.84399456527746
# iteration = 9 가중치 = 0.49641597046026836 Loss = 317.07355649335693
# iteration = 10 가중치 = 0.5645445494563797 Loss = -288.3468119205271
# iteration = 11 가중치 = 0.4781575112893105 Loss = 490.4508882852547
# iteration = 12 가중치 = 0.5876962756851543 Loss = -479.1780792425167
# iteration = 13 가중치 = 0.4488011224312244 Loss = 779.0698218195452
# iteration = 14 가중치 = 0.6249201767572075 Loss = -770.1501188594599
# iteration = 15 가중치 = 0.40160121587186093 Loss = 1268.6039717347371
# ...
